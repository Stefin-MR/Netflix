# %% [markdown]
# # Instructions

# %% [markdown]
# Read each of the following questions carefully, and provide an appropriate answer in the appropriate cell(s). Depending on the question, you may need to provide code or text. Be sure to label your answers with the question number so that they can be easily identified.

# %% [markdown]
# **Question 1: Which of the following statements is the correct way to import a csv into a Pandas DataFrame? (2 points)**
#
# A.
#
# ```python
# import pandas as pd
# infile = pd.read_csv(file_name)
# ```
#
#
# B.
#
# ```python
# import pandas as pd
# infile = pd.readCSV(file_name)
# ```
#
#
# C.
#
# ```python
# import pandas as pd
# infile = read_file(file_name)
# ```
#
#
# D.
#
# ```python
# import pandas as pd
# df.read_file(file_name)
# ```

# %%
# Answer 1
#1. A
# Out:
#   File "C:\Users\yet89\AppData\Local\Temp/ipykernel_16388/165272471.py", line 2
#     1. A
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Question 2: Write the code to do the following: (5 points)**
#
#   1. Import the `student.json` file into a Pandas DataFrame named `grades`.
#
#   2. Create a new DataFrame named `passing` that contains only the students whose `Pass/Fail` status equals `	PASS`.

# %%
# Answer 2
import pandas as pd
import os
grades = os.path.join('Resources','student.json')
df = pd.read_json(grades)
df
array = []
for index, row in df.iterrows():
    if row["Pass/Fail"] == "PASS":
        array.append(row)
        
print (array)
# Out:
# [Student Name     Jackqueline Durbin
# Midterm Exam                     85
# Midterm Paper                    84
# Final Exam                       90
# Final Paper                      56
# Final Grade                      79
# Pass/Fail                      PASS
# Letter Grade                      C
# Name: 0, dtype: object, Student Name     Lina Petters
# Midterm Exam               48
# Midterm Paper              57
# Final Exam                 97
# Final Paper                95
# Final Grade                74
# Pass/Fail                PASS
# Letter Grade                C
# Name: 1, dtype: object, Student Name     Hilaria Mcgehee
# Midterm Exam                  96
# Midterm Paper                100
# Final Exam                    97
# Final Paper                   87
# Final Grade                   95
# Pass/Fail                   PASS
# Letter Grade                   A
# Name: 2, dtype: object, Student Name     Raelene Bundy
# Midterm Exam                89
# Midterm Paper               57
# Final Exam                  90
# Final Paper                 85
# Final Grade                 80
# Pass/Fail                 PASS
# Letter Grade                 B
# Name: 4, dtype: object, Student Name     Wayne Mellor
# Midterm Exam               71
# Midterm Paper              93
# Final Exam                 97
# Final Paper                55
# Final Grade                79
# Pass/Fail                PASS
# Letter Grade                C
# Name: 5, dtype: object, Student Name     Sheena Bolten
# Midterm Exam                97
# Midterm Paper               90
# Final Exam                  70
# Final Paper                 83
# Final Grade                 85
# Pass/Fail                 PASS
# Letter Grade                 B
# Name: 6, dtype: object, Student Name     Ben Goforth
# Midterm Exam             100
# Midterm Paper             94
# Final Exam                90
# Final Paper               95
# Final Grade               95
# Pass/Fail               PASS
# Letter Grade               A
# Name: 8, dtype: object, Student Name     Alva Renshaw
# Midterm Exam               88
# Midterm Paper              61
# Final Exam                 45
# Final Paper                47
# Final Grade                60
# Pass/Fail                PASS
# Letter Grade                D
# Name: 9, dtype: object, Student Name     Mariana Hillwig
# Midterm Exam                  83
# Midterm Paper                 42
# Final Exam                    67
# Final Paper                   46
# Final Grade                   60
# Pass/Fail                   PASS
# Letter Grade                   D
# Name: 11, dtype: object, Student Name     Sang Pascarelli
# Midterm Exam                  54
# Midterm Paper                 47
# Final Exam                    92
# Final Paper                   57
# Final Grade                   63
# Pass/Fail                   PASS
# Letter Grade                   D
# Name: 13, dtype: object, Student Name     Arianna Wagar
# Midterm Exam                73
# Midterm Paper               98
# Final Exam                  59
# Final Paper                 73
# Final Grade                 76
# Pass/Fail                 PASS
# Letter Grade                 C
# Name: 14, dtype: object, Student Name     Antonio Kaur
# Midterm Exam               75
# Midterm Paper              72
# Final Exam                 87
# Final Paper                53
# Final Grade                72
# Pass/Fail                PASS
# Letter Grade                C
# Name: 15, dtype: object, Student Name     Alethea Wyllie
# Midterm Exam                 90
# Midterm Paper                97
# Final Exam                  100
# Final Paper                  97
# Final Grade                  96
# Pass/Fail                  PASS
# Letter Grade                  A
# Name: 16, dtype: object, Student Name     Concetta Lucht
# Midterm Exam                 95
# Midterm Paper                80
# Final Exam                   88
# Final Paper                  89
# Final Grade                  88
# Pass/Fail                  PASS
# Letter Grade                  B
# Name: 17, dtype: object, Student Name     Jude Capetillo
# Midterm Exam                 66
# Midterm Paper               100
# Final Exam                   93
# Final Paper                  82
# Final Grade                  85
# Pass/Fail                  PASS
# Letter Grade                  B
# Name: 18, dtype: object, Student Name     Gladis Rank
# Midterm Exam              46
# Midterm Paper             74
# Final Exam                92
# Final Paper               87
# Final Grade               75
# Pass/Fail               PASS
# Letter Grade               C
# Name: 19, dtype: object, Student Name     Luciano Cuffie
# Midterm Exam                 94
# Midterm Paper                92
# Final Exam                   86
# Final Paper                 100
# Final Grade                  93
# Pass/Fail                  PASS
# Letter Grade                  A
# Name: 20, dtype: object, Student Name     Damon Sohn
# Midterm Exam             53
# Midterm Paper            97
# Final Exam               74
# Final Paper              53
# Final Grade              69
# Pass/Fail              PASS
# Letter Grade              D
# Name: 23, dtype: object]

# %% [markdown]
# **Question 3: Write the code to create a Pandas DataFrame with the following columns and values: (5 points)**
#
# * `Stock_Symbol`: AAPL, GOOG, TSLA, KO, MSFT
# * `Company_Name`: Apple, Google, Tesla, Coca-Cola, Microsoft
# * `52_Week_High`: 145.09, 1934.86, 900.40, 60.13, 242.64

# %%
# Answer 3
import pandas as pd
Stocks= ["AAPL", "GOOG", "TSLA", "KO", "MSFT"]
Company = ["Apple","Google","Tesla","Coca-Cola","Microsoft"]
WH_52= ["145.09","1934.86","900.40","60.13","242.64"]
Stock_DF_Prep = {'Stocks': Stocks, 'Company': Company,"WH_52": WH_52}
df = pd.DataFrame(Stock_DF_Prep, columns = ["Stocks","Company","WH_52"])
df
# Out:
#   Stocks    Company    WH_52
# 0   AAPL      Apple   145.09
# 1   GOOG     Google  1934.86
# 2   TSLA      Tesla   900.40
# 3     KO  Coca-Cola    60.13
# 4   MSFT  Microsoft   242.64

# %% [markdown]
# **Question 4: Which of the following Git commands creates a new branch in your local repository? (2 points)**
#
# A. `git clone`
#
# B. `git pull <branch name>`
#
# C. `git checkout -b <branch name>`
#
# D. `git push -b <branch name>`

# %%
# Answer 4
git clone
# Out:
#   File "C:\Users\yet89\AppData\Local\Temp/ipykernel_16388/2570590077.py", line 2
#     git clone
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Question 5: Write the code to perform the following operations: (10 points)**
#
#    1. Import the `bitcoin_cash_price.csv` file into a Pandas DataFrame called `bitcoin`.
#
#    2. Import the `dash_price.csv` file into a Pandas DataFrame called `dash`.
#
#    3. Merge the `bitcoin` and `dash` DataFrames by using the Date column as the identifier column. Name this new merged DataFrame `crypto`.
#
#    4. Create a new Delta_Volume column in the `crypto` DataFrame that calculates the largest **absolute** difference between the Bitcoin volume and Dash volume.
#
#       * **Hint:** Use the `abs` function to calculate absolute value.
#
#    5. Find the row in the `crypto` DataFrame that contains the maximum “Delta_Volume” value. Print the row.

# %%
# Answer 5
import pandas as pd
import os
bitcoin = os.path.join('Resources','bitcoin_cash_price.csv')
dash = os.path.join('Resources','dash_price.csv')
bitcoin_df = pd.read_csv(bitcoin)
dash_df = pd.read_csv(dash)
crypto= pd.merge(bitcoin_df,dash_df,on="Date")
Delta_Volume = abs(bitcoin_df["Volume"] - dash_df["Volume"])
crypto["Delta_Volume"] = Delta_Volume
crypto
max(crypto["Delta_Volume"])
currentmax= 0 
for index, row in crypto.iterrows():
    if row["Delta_Volume"]>currentmax:
        currentmax = row["Delta_Volume"]
        rowmax = row
print (rowmax)
# Out:
# Date                18-Aug-17
# Open_x                 458.67
# High_x                 764.07
# Low_x                  458.67
# Close_x                690.24
# Volume_x         3087490000.0
# Market Cap_x    7,565,590,000
# Open_y                 233.84
# High_y                 240.41
# Low_y                  219.42
# Close_y                224.28
# Volume_y           50324200.0
# Market Cap_y    1,753,350,000
# Delta_Volume     3037165800.0
# Name: 30, dtype: object

# %% [markdown]
# **Question 6: You are asked to rename the following three columns in a DataFrame: `listing_price`, `appraisal_price`, and `selling_price` to `List Price`, `Appraisal Price`, and `Selling Price`.  How do you rename these columns (3 points)**
#
# A.
#
# ```python
# renamed_df = df.rename[columns={"listing_price":"Listing Price", "appraisal_price":"Appraisal Price"
#                                 ,"selling_price":"Selling Price"}]
# ```
#
# B.
#
# ```python
# renamed_df = df.rename(columns={"listing_price":"Listing Price", "appraisal_price":"Appraisal Price"
#                                 ,"selling_price":"Selling Price"})
# ```
#
# C.
#
# ```python
# renamed_df = df.rename{columns={"listing_price":"Listing Price", "appraisal_price":"Appraisal Price"
#                                 ,"selling_price":"Selling Price"}}
# ```
#
# D.
#
# ```python
# renamed_df = df.rename({"listing_price":"Listing Price", "appraisal_price":"Appraisal Price"
#                                 ,"selling_price":"Selling Price"})
# ```

# %%
# Answer 6
#6. B
renamed_df = df.rename(columns={"listing_price":"Listing Price", "appraisal_price":"Appraisal Price"
                                ,"selling_price":"Selling Price"})
# Out:
#           Student Name  Midterm Exam  Midterm Paper  Final Exam  Final Paper  \
# 0   Jackqueline Durbin            85             84          90           56
# 1         Lina Petters            48             57          97           95
# 2      Hilaria Mcgehee            96            100          97           87
# 3          Leroy Dress            52             52          64           63
# 4        Raelene Bundy            89             57          90           85
# 5         Wayne Mellor            71             93          97           55
# 6        Sheena Bolten            97             90          70           83
# 7        Shyla Cupples            67             62          48           43
# 8          Ben Goforth           100             94          90           95
# 9         Alva Renshaw            88             61          45           47
# 10       Lucio Elswick            44             87          43           55
# 11     Mariana Hillwig            83             42          67           46
# 12          Elna Doane            59             43          43           52
# 13     Sang Pascarelli            54             47          92           57
# 14       Arianna Wagar            73             98          59           73
# 15        Antonio Kaur            75             72          87           53
# 16      Alethea Wyllie            90             97         100           97
# 17      Concetta Lucht            95             80          88           89
# 18      Jude Capetillo            66            100          93           82
# 19         Gladis Rank            46             74          92           87
# 20      Luciano Cuffie            94             92          86          100
# 21        Oren Okelley            55             52          76           48
# 22            Ha Ruano            41             44          95           55
# 23          Damon Sohn            53             97          74           53
#
#     Final Grade Pass/Fail Letter Grade
# 0            79      PASS            C
# 1            74      PASS            C
# 2            95      PASS            A
# 3            58      FAIL            F
# 4            80      PASS            B
# 5            79      PASS            C
# 6            85      PASS            B
# 7            55      FAIL            F
# 8            95      PASS            A
# 9            60      PASS            D
# 10           57      FAIL            F
# 11           60      PASS            D
# 12           49      FAIL            F
# 13           63      PASS            D
# 14           76      PASS            C
# 15           72      PASS            C
# 16           96      PASS            A
# 17           88      PASS            B
# 18           85      PASS            B
# 19           75      PASS            C
# 20           93      PASS            A
# 21           58      FAIL            F
# 22           59      FAIL            F
# 23           69      PASS            D

# %% [markdown]
# **Question 7: Import the `donors.csv` file into a Pandas DataFrame. Using the `groupby` function, create a Series with the average amount for each state. How many states have averages greater than or equal to $750.00? (5 points)**
#
# A. 10
#
# B. 11
#
# C. 9
#
# D. 8

# %%
import pandas as pd
donors = os.path.join('Resources','donors2008.csv')
donors_df = pd.read_csv(donors)
donors_describe = pd.DataFrame(donors_df)
grouped_donors_df = donors_describe.groupby(['State'])
new_df = grouped_donors_df.describe()
new_df
#I manually counted and got 9...
#7. C
# Out:
#       Amount                                                                  \
#        count         mean          std    min     25%    50%     75%     max
# State
# AE       1.0   100.000000          NaN  100.0  100.00  100.0   100.0   100.0
# AK       6.0   175.000000   175.356779   50.0   62.50  100.0   212.5   500.0
# AL       8.0   212.500000   140.788595   50.0  100.00  225.0   250.0   500.0
# MT       0.0  NaN NaN NaN NaN NaN NaN NaN
# NC       0.0  NaN NaN NaN NaN NaN NaN NaN
# NE       0.0  NaN NaN NaN NaN NaN NaN NaN
# NH       0.0  NaN NaN NaN NaN NaN NaN NaN
# NJ       0.0  NaN NaN NaN NaN NaN NaN NaN
# NM       0.0  NaN NaN NaN NaN NaN NaN NaN
# NV       0.0  NaN NaN NaN NaN NaN NaN NaN
# NY       0.0  NaN NaN NaN NaN NaN NaN NaN
# OH       0.0  NaN NaN NaN NaN NaN NaN NaN
# OK       0.0  NaN NaN NaN NaN NaN NaN NaN
# OR       0.0  NaN NaN NaN NaN NaN NaN NaN
# PA       0.0  NaN NaN NaN NaN NaN NaN NaN
# QC       0.0  NaN NaN NaN NaN NaN NaN NaN
# RI       0.0  NaN NaN NaN NaN NaN NaN NaN
# SC       0.0  NaN NaN NaN NaN NaN NaN NaN
# TN       0.0  NaN NaN NaN NaN NaN NaN NaN
# TX       0.0  NaN NaN NaN NaN NaN NaN NaN
# UT       0.0  NaN NaN NaN NaN NaN NaN NaN
# VA       0.0  NaN NaN NaN NaN NaN NaN NaN
# VI       0.0  NaN NaN NaN NaN NaN NaN NaN
# VT       0.0  NaN NaN NaN NaN NaN NaN NaN
# WA       0.0  NaN NaN NaN NaN NaN NaN NaN
# WI       0.0  NaN NaN NaN NaN NaN NaN NaN
# WV       0.0  NaN NaN NaN NaN NaN NaN NaN
# WY       0.0  NaN NaN NaN NaN NaN NaN NaN

# %%
# Answer 7

# %% [markdown]
# **Question 8: What piece of code defines the beginning of a Python function? (1 point)**
#
#
# A. `print_name()`
#
# B. `def`
#
# C. `def()`
#
# D. `define()`

# %%
# Answer 8
#8. B

# %% [markdown]
# **Question 9: Read in the `earthquakes_database.csv` file into a Pandas DataFrame. What day had the most earthquakes? (Hint: Use Pandas' built-in functions to find the answer.) (5 points)**
#
# A. `2/6/13`
#
# B. `12/26/04`
#
# C. `3/12/11`
#
# D. `3/11/11`

# %%
import pandas as pd
import os
Earthquakes = os.path.join('Resources','earthquakes_database.csv')
Earthquakes_df= pd.read_csv(Earthquakes)
Earthquakes_df["Date"].mode()
#9.D
# Out:
# 0    3/11/11
# dtype: object

# %%
# Answer 9

# %% [markdown]
# **Question 10: Write code that performs the following operations *without* using Pandas: (12 points)**
#
# 1. Opens and reads the `cereal.csv` file.
# 2. Skips the header row.
# 3. Reads each row.
# 4. Prints out the cereals that contain 5 or more grams of fiber.

# %%
import os
import csv
csvpath = os.path.join('Resources','cereal.csv')
with open (csvpath) as csvfile:
    csvDictReader = csv.DictReader(csvfile)
    printrow = []
    for row in csvDictReader:
        fiber = float(row['fiber'])
        if fiber > 5:
            printrow.append(row['name'])   
printrow
# Out:
# ['100% Bran', 'All-Bran', 'All-Bran with Extra Fiber', 'Post Nat. Raisin Bran']

# %%
# Answer 10
